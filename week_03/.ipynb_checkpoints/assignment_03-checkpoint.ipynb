# %% [markdown]
# ### Exercise 1:
# Study the following code and create your own mad-libs generator (please don't copy the example)

# %% [markdown]
# ### A Mad-Libs invitation generator
#
# Mad-Libs is a phrasal template word game where one player prompts others for a list of words to <b>substitute</b> for blanks in a story.
#
# We are going to create an event `invitation function` that would allow us to automate creating copies of event invitations.
#
# <span style="color:tomato">The invitation template</span>:
# ```
#     Hey, _guestname_!
#     You are invited to a _type_of_event_! Join us on _date_ at _location_!
#     Bring _items_.
#
#     Best,
#     Party bear
#
# ```
#
# <span style="color:tomato">An example output</span>:
# ```
#     Hey, Sven!
#     You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#     Bring beverages, games, signs, masks, and facecovers.
#
#     Best,
#     Party bear
# ```

# %%
# EXAMPLE GENERATOR

import random
def event(namelist, event_type, date, loc, items):
    """
        This function takes event information input, parse them and turn them into
        a formatted invitation that's ready to be duplicate and populate.
    """
    # outputs a random item from the list
    def getRand(list):
        return random.choice(list)
    
    # formats all outputs form a list as 'a, b, and c'
    def getAll(li):
        return ', '.join(li[:-1]) + ", and %s" %(li[-1])
    
  
    # variables needed:
    guestlist = namelist
    type_of_event = event_type
    date = date[::-1]
    location = loc[::-1] # a simple reversed encrption
    items = items
    invite_template = '''
            Hey %s:
            You are invited to a %s! Join us on %s at %s!
            Bring %s.

            Best,
            Party bear

            ---
        ''' 
    
    # loop through all guest tuples in the guestlist
    # populate our invitations
    for guests in guestlist:
        print(invite_template % (guests,
                                 type_of_event,
                                 date,
                                 location,
                                 getAll(items)# try getRand()
                                ))

# %%
guests = ("Bob","Mary & Friends","Lan","Anna","Sven and friends","Jason")
items = ['beverages','games','signs',"masks","facecovers"]

# call the generator function to populate invitations:
event(guests, "gathering", "July 2nd", "Union Square", items)

# %%
# Exercise 1 Code Here:

import random

def event(namelist, event_type, date, loc, items):

    # outputs a random item from the list
    def getRand(list):
        return random.choice(list)
    
    # formats all outputs form a list as 'a, b, and c'
    def getAll(li):
        return ', '.join(li[:-1]) + ", and %s" %(li[-1])
    
  
    invitation_template = '''
            Hey %s:
            You are invited to our %s! Join us on %s at %s!
            All you need to bring with you is %s.

            Best,
            Mia & Jill

            ---
        ''' 
    
    # loop through all guest tuples in the guestlist
    # populate our invitations
    for guests in namelist:
        print(invitation_template % (guests,
                                 event_type,
                                 date,
                                 loc,
                                 getRand(items)
                                ))
        
guests = ("Tiffany","Kathryn","Jazsalyn","Sohee","Jason","Franzi","Jill","Joseph", "Baichao")
items = ["drinks","some pesto ingredients","a big appetite"]

# call the generator function to populate invitations:
event(guests, "Valentine's Pasta Party", "14th of February", "our new place", items)
# Out:
#             Hey Tiffany:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is drinks.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Kathryn:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is some pesto ingredients.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Jazsalyn:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is drinks.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Sohee:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is some pesto ingredients.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Jason:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is a big appetite.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Franzi:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is some pesto ingredients.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Jill:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is some pesto ingredients.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Joseph:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is a big appetite.
#
#             Best,
#             Mia & Jill
#
#             ---
#
#
#             Hey Baichao:
#             You are invited to our Valentine's Pasta Party! Join us on 14th of February at our new place!
#             All you need to bring with you is drinks.
#
#             Best,
#             Mia & Jill
#
#             ---

# %% [markdown]
# ### Exercise 2:
#
# ### What is a palindrome?
# A palindrome is a word or phrase that is spelled the same forwards as backwards, like:
#
# ```
# wow
# Anna
# race car
# Was it a cat I saw?
# ```
#
# Create a function that checks whether or not a given phrase is a palindrome. Here's the plan:
# * Our function will be called `isPalindrome()`.
# * It will accept one **argument** called `txt`, which is a string.
# * It will print True if `txt` is a palindrome or `False` if `txt`
#   is not a palindrome.
#
# ### Test your function along the way
# We will use the following test cases to guide us:
#
# The following should all return `True`:
# ```
# isPalindrome('wow')
# isPalindrome('12a3a21')
# isPalindrome('Anna')
# isPalindrome('race car')
# isPalindrome('Was it a cat I saw?')
# ```
#
# The following should all return `False`:
# ```
# isPalindrome('wowza')
# isPalindrome('123a21')
# isPalindrome('<3 mom <3')
# ```
#
# ### Things to Consider:
#  - Make everything lowercase.
#  - Replace all spaces with an empty string
#  - Replace all spaces with an empty string
#  - How would we spell a word backwards or forwards?

# %%
# Exercise 2 Code Here:

# Pseudocode:
# Step 1: take user input
# Step 2: function to format words to fit it to be nospace + lowercase
# Step 3: function checking for palindrome
# Step 4: Print messages



def isPalindrome(words):
    wordsNew = words.lower().replace(" ","")
    #print(wordsNew)
    
    wordlenght = len(wordsNew)
    charFromFront = 0
    charFromBack = -1
    #print(charFromFront)
    #print(charFromBack)
    state = 1
    
    while(charFromFront < charFromBack):
        if (wordsNew[charFromFront] == wordsNew[charFromBack]):
            charFromFront = charFromFront + 1
            charFRomBack = charFromFront -1
        else:
            state = 0
            break
            
    return int(status)

            
words = str(input("Enter your potential palindrome:"))
state = isPalindrome(words)

if (state == True):
    print("IT'S A PALINDROME YAY!!!")
    
elif (state == False):
    print("Ohno, it's not a palindrome.")
# Out:
# Enter your potential palindrome:WaS IT a CAT I saw
# IT'S A PALINDROME YAY!!!

# %% [markdown]
# ### Exercise 3:
# Create a dataset of your own using using a dictionary and make a simple visualization with it. Branch out and see what types of graphs you could use here: https://matplotlib.org/ . Don't be shy to Google things you don't know!!!

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# Exercise 3 Code Here:
# A DICTIONARY OF MY PLANTS & How large they are approx. in cm

import matplotlib.pyplot as plt
import numpy as np

my_plants = {
    'monstera': 110, 
    'one_leaf': 80, 
    'dragon_tree': 120, 
    'basil': 30, 
    'thyme': 15,
    'mini_monstera': 60, 
    'forgotitsname': 40,
    'palmtree': 170
    }


plt.bar(range(len(my_plants)), list(my_plants.values()), align='center', color=['green'])
plt.xticks(range(len(my_plants)), list(my_plants.keys()), rotation = 45)
plt.show()
