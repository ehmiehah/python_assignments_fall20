# %% [markdown]
# ### Analyzing the New York Times comments section
#
# For this assignment, inspect the <a href="https://developer.nytimes.com/">NYT API</a>, specifically their API for article comments. We'll be completing two major tasks:
# - find out where people are commenting from
# - get the most common words from a specific comment

# %%
# import requests and json
import requests
import json

# put your custom settings for the API call here
# you MUST provide an API key, offset value, and article URL
# get your api key from here: https://developer.nytimes.com/
api_key = "OGoLO2xHyVXNYAb0QGgNSnwWQzrLvv0a"
offset = str(42)
article_url = "https://www.nytimes.com/2020/06/12/opinion/sunday/floyd-protests-white-supremacy.html"
sort = "reader"

# show the API url with all the settings listed out
api_url = "https://api.nytimes.com/svc/community/v3/user-content/url.json?api-key=%s&offset=%s&sort=%s&url=%s" %(api_key, offset, sort, article_url)
print(api_url)
# Out:
# https://api.nytimes.com/svc/community/v3/user-content/url.json?api-key=OGoLO2xHyVXNYAb0QGgNSnwWQzrLvv0a&offset=42&sort=reader&url=https://www.nytimes.com/2020/06/12/opinion/sunday/floyd-protests-white-supremacy.html

# %%
# calling the API with requests
response = requests.get(api_url)
# creating a variable called data to hold the json formatted result
data = response.json()

# %%
# look at all of the data
# it's a lot of nested dictionaries!
print(type(data))
data
# Out:
# <class 'dict'>
# {'debug': {'version': 4, 'nyt-com-shim': True},
#  'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'results': {'callerID': None,
#   'api_timestamp': '1606561923',
#   'comments': [{'commentID': 107567029,
#     'status': 'approved',
#     'commentSequence': 107567029,
#     'userID': 57148903,
#     'userDisplayName': 'Formerly In The Trenches',
#     'userLocation': 'Atlanta',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'I’ve lived in Atlanta for 40 years. On a daily basis I hear people defend the monuments celebrating Confederate “war heroes.” I understand that for some, they can tie one or more family members to what is still referred to as “the war of Northern aggression.” The mindset of the Confederacy is still alive and thriving in the South. There is still anger that is carried from one generation to the next and it boils down to white supremacy. This is still a very strong and powerful ideal within a certain segment of the Southern population. Family historical memory is a powerful, albeit often flawed, determinant.',
#     'createDate': '1591965553',
#     'updateDate': '1592155134',
#     'approveDate': '1591965554',
#     'recommendations': 38,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107567029',
#     'isAnonymous': False},
#    {'commentID': 107566618,
#     'status': 'approved',
#     'commentSequence': 107566618,
#     'userID': 33118370,
#     'userDisplayName': 'Frank',
#     'userLocation': 'Boston',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "While we are at it, let's re-name Columbia University.\n\nAnd re-name the District of Columbia.\n\nBecause sales of naming rights are so lucrative, I think we should hold auctions, just like the Harvard School of Public Health was purchased by Gerald Chan, and the Mt. Sinai School of Medicine was purchased by Carl Icahn.\n\nThat, at least, would have the ring of honesty about who really runs the USA:  The District of Zuckerberg and Buffet University.",
#     'createDate': '1591964603',
#     'updateDate': '1592179391',
#     'approveDate': '1591964604',
#     'recommendations': 37,
#     'replyCount': 2,
#     'replies': [{'commentID': 107569296,
#       'status': 'approved',
#       'commentSequence': 107569296,
#       'userID': 52465399,
#       'userDisplayName': 'Paul',
#       'userLocation': 'Philadelphia, PA',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@Frank \n"While we are at it, let\'s re-name Columbia University.\nAnd re-name the District of Columbia."\n\nIt\'s long overdue, in fact.',
#       'createDate': '1591970397',
#       'updateDate': '1591986933',
#       'approveDate': '1591984588',
#       'recommendations': 2,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107566618,
#       'parentUserDisplayName': 'Frank',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107569296',
#       'isAnonymous': False},
#      {'commentID': 107569171,
#       'status': 'approved',
#       'commentSequence': 107569171,
#       'userID': 25676827,
#       'userDisplayName': 'MDCOOKS8',
#       'userLocation': 'West Of The Hudson',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': 'https://s3.amazonaws.com/pimage.timespeople.nytimes.com/avatars/cropped-7bb04d57fae25e942edf724a48a24f9d8184c9800ff8fe031e4c0b2a6caab0a7.jpg',
#       'commentTitle': '<br\\//>',
#       'commentBody': 'Then the name “Amazon” or “Bezos” might become as common as the word “Peach” on street names in Georgia...',
#       'createDate': '1591970155',
#       'updateDate': '1592007796',
#       'approveDate': '1592007796',
#       'recommendations': 0,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107566618,
#       'parentUserDisplayName': 'Frank',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107569171',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107566618',
#     'isAnonymous': False},
#    {'commentID': 107567855,
#     'status': 'approved',
#     'commentSequence': 107567855,
#     'userID': 69555093,
#     'userDisplayName': 'kim',
#     'userLocation': 'nyc',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'The fact that a goodly number of white Americans continue to support Donald Trump is astonishing.',
#     'createDate': '1591967420',
#     'updateDate': '1593281473',
#     'approveDate': '1592018852',
#     'recommendations': 36,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107567855',
#     'isAnonymous': False},
#    {'commentID': 107568319,
#     'status': 'approved',
#     'commentSequence': 107568319,
#     'userID': 21491150,
#     'userDisplayName': 'GBR',
#     'userLocation': 'New England',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'I was astounded to learn that some of our military bases are named after Confederate generals. That’s as nonsensical as naming a US military base for a British general who we defeated in the Revolutionary War. They should be renamed without question.',
#     'createDate': '1591968479',
#     'updateDate': '1592155982',
#     'approveDate': '1591968522',
#     'recommendations': 33,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107568319',
#     'isAnonymous': False},
#    {'commentID': 107569147,
#     'status': 'approved',
#     'commentSequence': 107569147,
#     'userID': 51505222,
#     'userDisplayName': 'Daniel',
#     'userLocation': 'Silver Spring MD',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Monuments erected to celebrate "confederate heroes" and "mythic explorers" are potent relics of our history, and should be preserved in a Museum of Racism, much like the Apartheid Museum in Johannesburg or the Holocaust Museum in Washington DC.',
#     'createDate': '1591970106',
#     'updateDate': '1593758549',
#     'approveDate': '1592018852',
#     'recommendations': 31,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107569147',
#     'isAnonymous': False},
#    {'commentID': 107569687,
#     'status': 'approved',
#     'commentSequence': 107569687,
#     'userID': 30276383,
#     'userDisplayName': 'Alan Richards',
#     'userLocation': 'Santa Cruz, CA',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Yes! ALL statues to Confederates should go! Just ask yourself: "How many statues to Nazi generals and politicians do you see today in Germany?" There are exactly ZERO such statues. The same should be true of Confederates, who violently supported a vicious, violent, evil social system.\n\nWhat, exactly, is hard to understand here??\n\nPS: This from a 73 year old white guy who grew up in Dallas, TX. I was delighted to see that Dallas has made some progress here, getting rid of the statue of Lee in a well-known park on Turtle Creek. It\'s a start.',
#     'createDate': '1591971124',
#     'updateDate': '1592919354',
#     'approveDate': '1592018850',
#     'recommendations': 31,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107569687',
#     'isAnonymous': False},
#    {'commentID': 107573878,
#     'status': 'approved',
#     'commentSequence': 107573878,
#     'userID': 77762355,
#     'userDisplayName': 'Paul',
#     'userLocation': 'CA',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'To end white supremacy we need to stop places like Fox News, Limbaugh, Breitbart, and Facebook pages that push it. They have caused the huge increase in white supremacy.',
#     'createDate': '1591979529',
#     'updateDate': '1592172617',
#     'approveDate': '1592018850',
#     'recommendations': 31,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107573878',
#     'isAnonymous': False},
#    {'commentID': 107575284,
#     'status': 'approved',
#     'commentSequence': 107575284,
#     'userID': 62195249,
#     'userDisplayName': 'VirginiaDude',
#     'userLocation': 'Culpepper, Virginia',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Sorry, I live here in the south and this movement is starting to take on an anti-white (or Euro-American) ferocity that reminds me of the McCarthy days.  Disagreement with anything being spouted by the BLM movement or democrats is met with cries of "you\'re a White supremacist" and the "cancel culture" mob.\n\nDefend Columbus? You\'re a White supremacist!\nHonor Thomas Jefferson?  You\'re a White supremacist!\nDefend European culture?  You\'re a White supremacist!\n\nI believe this new McCarthyism will soon stir a backlash that will engulf us all and bring this country to a breaking point.  You can only kick a dog so many times before it bites.',
#     'createDate': '1591982849',
#     'updateDate': '1592625080',
#     'approveDate': '1592018290',
#     'recommendations': 31,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107575284',
#     'isAnonymous': False},
#    {'commentID': 107564653,
#     'status': 'approved',
#     'commentSequence': 107564653,
#     'userID': 63645109,
#     'userDisplayName': 'Sunspot',
#     'userLocation': 'Concord, MA',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "BLM is winning by capturing the spotlight and focusing our attention back on who we are and what we can become. Let's not lose our precious momentum! In our actions, in our hearts and at the polls, let's embrace our multi-colored and rainbow destiny with resolve, creativity, grit and imagination. Environmental justice is a priority: toppling white supremacy means renaming military bases and replacing monuments -- but it also means clean air, clean water, trees and farmers' markets in every barrio.",
#     'createDate': '1591958058',
#     'updateDate': '1592156116',
#     'approveDate': '1591958059',
#     'recommendations': 30,
#     'replyCount': 1,
#     'replies': [{'commentID': 107564786,
#       'status': 'approved',
#       'commentSequence': 107564786,
#       'userID': 59490369,
#       'userDisplayName': 'Glenn S.',
#       'userLocation': 'Ft. Lauderdale',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': 'How does taking over city blocks with armed guards fit into that narrative?',
#       'createDate': '1591958758',
#       'updateDate': '1591986759',
#       'approveDate': '1591970360',
#       'recommendations': 3,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107564653,
#       'parentUserDisplayName': 'Sunspot',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107564786',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107564653',
#     'isAnonymous': False},
#    {'commentID': 107569378,
#     'status': 'approved',
#     'commentSequence': 107569378,
#     'userID': 50997515,
#     'userDisplayName': 'R Dubrey IV',
#     'userLocation': 'Fayetteville, AR',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "Mercifully just because the media echo chamber keeps repeating this garbage doesn't make it true.   We would all have died years ago in some crisis if we are to believe anything you people opine about.   Stick to the facts.   You are only marginally good at that.",
#     'createDate': '1591970530',
#     'updateDate': '1593013985',
#     'approveDate': '1592018855',
#     'recommendations': 29,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107569378',
#     'isAnonymous': False},
#    {'commentID': 107575359,
#     'status': 'approved',
#     'commentSequence': 107575359,
#     'userID': 62071854,
#     'userDisplayName': 'Deborah Adams',
#     'userLocation': 'Boise, Idaho',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "Jamelle, it is not a white supremacy problem, but rather, it is the diversity of America.      I am a deaf white woman.  If you go to France, all you see is mostly French.  If you go to Ireland, all you see is mostly Irish.   If you go to Nigeria, all you see is mostly black people.  But here in America, you meet all kinds of people.       America has many many different lives, not just black people but also deaf lives, blind lives, Chinese lives, Irish lives, many many other lives.      Tearing down monuments is a rather self-centered view of yours, because  not only black people but also deaf people, blind people, disabled people, Chinese people, Irish people, many many others experienced subjugation.     Now that the protest marches have helped America take a closer look at police brutality, why don't you just relax and enjoy your freedom as an American that many others across the Atlantic Ocean don't have?",
#     'createDate': '1591983067',
#     'updateDate': '1592168334',
#     'approveDate': '1591984887',
#     'recommendations': 27,
#     'replyCount': 1,
#     'replies': [{'commentID': 107579034,
#       'status': 'approved',
#       'commentSequence': 107579034,
#       'userID': 68307996,
#       'userDisplayName': 'Carl',
#       'userLocation': 'Lansing, MI',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@Deborah Adams \n\n"Now that the protest marches have helped America take a closer look at police brutality, why don\'t you just relax and enjoy your freedom as an American that many others across the Atlantic Ocean don\'t have?"\n\nBecause America still has a long way to go before it lives up to the promises of the Declaration of Independence and to the equal protections professed by the Constitution. \n\nThese times do not call for complacency they call for action. \n\n"All that it takes for evil to succeed is for good people to do nothing."',
#       'createDate': '1591995899',
#       'updateDate': '1592015390',
#       'approveDate': '1592015390',
#       'recommendations': 0,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107575359,
#       'parentUserDisplayName': 'Deborah Adams',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107579034',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107575359',
#     'isAnonymous': False},
#    {'commentID': 107564588,
#     'status': 'approved',
#     'commentSequence': 107564588,
#     'userID': 59095799,
#     'userDisplayName': 'Gary Cohen',
#     'userLocation': 'Great Neck NY',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Every four years the Democrats pander for Votes from people of color but offer little in real structural change ( the exception was ACA which benefits everyone). So why should people of color believe Biden when his main argument is I am not Trump?',
#     'createDate': '1591957708',
#     'updateDate': '1592178806',
#     'approveDate': '1591957709',
#     'recommendations': 26,
#     'replyCount': 5,
#     'replies': [{'commentID': 107568170,
#       'status': 'approved',
#       'commentSequence': 107568170,
#       'userID': 54971898,
#       'userDisplayName': 'Albert Petersen',
#       'userLocation': 'Boulder, Co',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@Gary Cohen  Because for those who believe in the Constitution and a Democratic America think the "not Trump" is enough!',
#       'createDate': '1591968138',
#       'updateDate': '1592013603',
#       'approveDate': '1591968138',
#       'recommendations': 6,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107564588,
#       'parentUserDisplayName': 'Gary Cohen',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107568170',
#       'isAnonymous': False},
#      {'commentID': 107567990,
#       'status': 'approved',
#       'commentSequence': 107567990,
#       'userID': 54091507,
#       'userDisplayName': 'Darrel Lauren',
#       'userLocation': 'Williamsburg',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@Gary Cohen  seriously? Plato knew that the cost of indifference to civic duty was government by bad people. This isn’t about what can you squeeze out of the government for yourself, it’s about what’s best for the country. And the contrast is stark. Bannon’s objective has been fulfilled, trump has torn apart the constitution and the country- for all races.',
#       'createDate': '1591967703',
#       'updateDate': '1591992571',
#       'approveDate': '1591970360',
#       'recommendations': 3,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107564588,
#       'parentUserDisplayName': 'Gary Cohen',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107567990',
#       'isAnonymous': False},
#      {'commentID': 107564998,
#       'status': 'approved',
#       'commentSequence': 107564998,
#       'userID': 58933770,
#       'userDisplayName': 'JerryV',
#       'userLocation': 'NYC',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': "@Gary Cohen, If you believe that this is Biden's main argument, it seems clear you are. not listening. The large majority of Black Americans supporting Biden demonstrates their understanding that he is on their side. Perhaps you are disappointed that Black people have tended to support Biden over Sanders.  Please accept that the race between them is over.",
#       'createDate': '1591959843',
#       'updateDate': '1591992588',
#       'approveDate': '1591970849',
#       'recommendations': 4,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107564588,
#       'parentUserDisplayName': 'Gary Cohen',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107564998',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107564588',
#     'isAnonymous': False},
#    {'commentID': 107565114,
#     'status': 'approved',
#     'commentSequence': 107565114,
#     'userID': 58087840,
#     'userDisplayName': 'Buck Rutledge',
#     'userLocation': 'Knoxville, TN',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Hopefully, by November, "Trump fatigue" will prompt people to use the ballot for removing the largest obstacle to a more perfect union.',
#     'createDate': '1591960263',
#     'updateDate': '1592157190',
#     'approveDate': '1591960264',
#     'recommendations': 25,
#     'replyCount': 1,
#     'replies': [{'commentID': 107565577,
#       'status': 'approved',
#       'commentSequence': 107565577,
#       'userID': 70894043,
#       'userDisplayName': 'Jean claude the damned',
#       'userLocation': 'Bali',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': "@Buck Rutledge That's what you think!  I see what the new left (I was the old left) looks like with a little blood on its lips.  What a vicious turn they took.   This will not end well for democrats and for democracy.",
#       'createDate': '1591961834',
#       'updateDate': '1592179109',
#       'approveDate': '1591975472',
#       'recommendations': 3,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107565114,
#       'parentUserDisplayName': 'Buck Rutledge',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107565577',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107565114',
#     'isAnonymous': False},
#    {'commentID': 107564931,
#     'status': 'approved',
#     'commentSequence': 107564931,
#     'userID': 40651927,
#     'userDisplayName': 'ttrumbo',
#     'userLocation': 'Fayetteville, Ark.',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "We need to speak economics. We need to see that self-government is easily lost to the rich and their lobbyists and lawyers, bought politicians and judges, media and conspiracy fake stories, unless we are vigilant. We have not been.\n\nThe two monumental challenges of today are inequality (which includes poverty, concentrated wealth, and racism) and global climatic catastrophe. We can do both. We can do anything.\n\nThere are so many good people taking to the streets to honor George Floyd and to call for 'justice' and an end to police violence and murder. Good Americans doing the work of America. And, they also feel something else, something missing, something not right, here. \n\nWe cannot have ghettos. We cannot have billionaires. We must have the 'more perfect Union' and that means economics, quality of life, standard of living. Basic human needs are basic human rights: food, clothing, shelter, safety, a decent-paying job. Beyond that we need respect, belonging, appreciation, community, love. We the People need. All of US.\n\nThe virus is part of this watershed; maybe God's way of giving us a chance to save ourselves. We could not have gone on the same path for long. We reward too few and hurt too many. We destroy the planet that is our home. Yes, great changes are coming, whether we are part of the good change or a victim of the bad. We are here. It is a climactic moment.\n\nWe are from the stars, holy, sacred. We the People of the stars can do anything we want to do. Let's go.",
#     'createDate': '1591959509',
#     'updateDate': '1592059626',
#     'approveDate': '1591959510',
#     'recommendations': 24,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107564931',
#     'isAnonymous': False},
#    {'commentID': 107568604,
#     'status': 'approved',
#     'commentSequence': 107568604,
#     'userID': 58734095,
#     'userDisplayName': 'Charles B. Manuel, Jr.',
#     'userLocation': 'New York',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'To Overturn Trump, We Need to Overturn White Supremacy\n\nAnd vice versa.',
#     'createDate': '1591969034',
#     'updateDate': '1593281480',
#     'approveDate': '1592018852',
#     'recommendations': 24,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107568604',
#     'isAnonymous': False},
#    {'commentID': 107572644,
#     'status': 'approved',
#     'commentSequence': 107572644,
#     'userID': 66282869,
#     'userDisplayName': 'OneView',
#     'userLocation': 'Boston',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'I keep thinking of the statues of the Budda in Afghanistan.  It seems our new left are the new Taliban.',
#     'createDate': '1591976909',
#     'updateDate': '1592179695',
#     'approveDate': '1592018289',
#     'recommendations': 24,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107572644',
#     'isAnonymous': False},
#    {'commentID': 107564486,
#     'status': 'approved',
#     'commentSequence': 107564486,
#     'userID': 77044708,
#     'userDisplayName': 'Penelope Trees',
#     'userLocation': 'Indianapolis IN',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "What a shame that statues topple...they signify a part of our history.   If we remove statues, does that mean that slavery didn't happen?",
#     'createDate': '1591957047',
#     'updateDate': '1592087871',
#     'approveDate': '1591957386',
#     'recommendations': 23,
#     'replyCount': 7,
#     'replies': [{'commentID': 107566251,
#       'status': 'approved',
#       'commentSequence': 107566251,
#       'userID': 42403582,
#       'userDisplayName': 'Mike',
#       'userLocation': 'near Chicago',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': 'To the extent that statues are "history," Confederate statues are REVISIONIST history. They are an attempt to turn Confederate defeat into Confederate victory.\n\nIn reality, statues aren\'t history at all.  To be sure, they interpret history; they declare which people are the heroes. People who object to the removal of statues of Lee and Davis aren\'t really objecting to "changing history"; they\'re objecting to the public recognition that Confederate heroes aren\'t American heroes.',
#       'createDate': '1591963690',
#       'updateDate': '1592207441',
#       'approveDate': '1591963691',
#       'recommendations': 11,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107564486,
#       'parentUserDisplayName': 'Penelope Trees',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107566251',
#       'isAnonymous': False},
#      {'commentID': 107564580,
#       'status': 'approved',
#       'commentSequence': 107564580,
#       'userID': 76479425,
#       'userDisplayName': 'David S',
#       'userLocation': 'New Jersey',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': 'No. Put up a plaque to tell people of the history. Put up a statue of the real heroes. Tell the history through the lens of Tubman, King, Evers, Parks and so many more.',
#       'createDate': '1591957633',
#       'updateDate': '1592087308',
#       'approveDate': '1591970371',
#       'recommendations': 5,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107564486,
#       'parentUserDisplayName': 'Penelope Trees',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107564580',
#       'isAnonymous': False},
#      {'commentID': 107565138,
#       'status': 'approved',
#       'commentSequence': 107565138,
#       'userID': 79120187,
#       'userDisplayName': 'S.C.',
#       'userLocation': 'NY',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@Penelope Trees \nNo but it means that we no longer glorify those who fought in support of it.\n\nThe statues should be dismantled and moved to less prominent places.',
#       'createDate': '1591960360',
#       'updateDate': '1592108147',
#       'approveDate': '1591970371',
#       'recommendations': 7,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107564486,
#       'parentUserDisplayName': 'Penelope Trees',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107565138',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107564486',
#     'isAnonymous': False},
#    {'commentID': 107565502,
#     'status': 'approved',
#     'commentSequence': 107565502,
#     'userID': 89708467,
#     'userDisplayName': 'Zé Povinho',
#     'userLocation': 'Charlottesville, Virginia',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': "I couldn't agree more on Confederate statues but not so much your arguments for removing Columbus.   The former rose against our country in an armed rebellion, and the statues themselves represent the impositioin of the Lost Cause myth and the attempt to continue to keep black Americans in ersatz slavery.  But you're subjecting Columbus to a personal rather than institutional evaluation.  His reality merits a much more nuanced reading than this--one you're all too capable of.  Any statue of Marion Barry wouldn't withstand a similar personal examination.",
#     'createDate': '1591961586',
#     'updateDate': '1592015826',
#     'approveDate': '1591961587',
#     'recommendations': 23,
#     'replyCount': 4,
#     'replies': [{'commentID': 107568063,
#       'status': 'approved',
#       'commentSequence': 107568063,
#       'userID': 77910675,
#       'userDisplayName': 'KV',
#       'userLocation': 'Boston',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': 'Yes.  Please read Columbus’ journals closely.  He’s even worse when you read the primary sources.  By all means take a closer look.',
#       'createDate': '1591967877',
#       'updateDate': '1591990231',
#       'approveDate': '1591970370',
#       'recommendations': 4,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107565502,
#       'parentUserDisplayName': 'Zé Povinho',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107568063',
#       'isAnonymous': False},
#      {'commentID': 107569454,
#       'status': 'approved',
#       'commentSequence': 107569454,
#       'userID': 54052612,
#       'userDisplayName': 'AaronS',
#       'userLocation': 'Florida',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': 'May I suggest that perhaps a more nuanced reading of the Confederacy is also in order?  Consider, my friend, that in Britain\'s eyes, our founders were guilty of treason, armed rebellion, etc.\n\nNo one, not George Washington, not Thomas Jefferson, not Abraham Lincoln, and not Dr. Martin Luther King, Jr., can withstand the full scrutiny of those determined to find wrong.  As for Dr. MLK, Jr., his best friend, Ralph Abernathy, in "And the Walls Came Tumblin\' Down," made it clear that Dr. MLK was a serial adulterer.    \n\nThis noble man, this man of God, was flawed.  As was King David.  As was George Washington.  As are we all.  But if perfection is the standard by which we judge, then there will be exactly one statue allowed, and He is has no need for statues.\n\nWe rightfully recognize John Brown, though he was a violent vigilante.  We rightfully recognize Nat Turner, even though women and children were massacred.  But it\'s somehow wrong to recognize good and noble men who did good service for America before and after the Civil War?   \n\nHad Reconstruction not been as harsh as it was (due to Lincoln\'s assassination), there probably would not have been the same notorious reaction in the South.  After all, they knew they were beat...but just like the Versailles Treaty, the surrender, in some ways, was as bad as the war.  \n\nThe South committed a grievous sin toward God and man.  But to act as if there can be no good thing at all in these men...that\'s outrage, not reason.',
#       'createDate': '1591970674',
#       'updateDate': '1592179165',
#       'approveDate': '1591970675',
#       'recommendations': 3,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107565502,
#       'parentUserDisplayName': 'Zé Povinho',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107569454',
#       'isAnonymous': False},
#      {'commentID': 107565790,
#       'status': 'approved',
#       'commentSequence': 107565790,
#       'userID': 70882338,
#       'userDisplayName': 'Daoud',
#       'userLocation': 'al Needleawi',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@Zé Povinho By the authors logic and his principles that Marion Barry statue should be torn down too. More than one can play at that game. Also, why stop there? Why not vandalize graves and dig up coffins and smash the bones a la North Korea? Perhaps the authors ancestors were less than stellar and should be retroactively punished for their crimes as well.',
#       'createDate': '1591962519',
#       'updateDate': '1591980368',
#       'approveDate': '1591975465',
#       'recommendations': 1,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107565502,
#       'parentUserDisplayName': 'Zé Povinho',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107565790',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107565502',
#     'isAnonymous': False},
#    {'commentID': 107566454,
#     'status': 'approved',
#     'commentSequence': 107566454,
#     'userID': 31380677,
#     'userDisplayName': 'Uncommon Wisdom',
#     'userLocation': 'Washington DC',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': 'https://s3.amazonaws.com/pimage.timespeople.nytimes.com/avatars/cropped-c7abeb2a8f3743c1351332a8a1a38f154c80feb5c85d655564ab6ab56bfb984d.jpg',
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Mahatma Gandhi was a well-known bigot who made racist statements towards Africans. To be fair we should tear down statues of him as well',
#     'createDate': '1591964195',
#     'updateDate': '1593751238',
#     'approveDate': '1592018850',
#     'recommendations': 23,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107566454',
#     'isAnonymous': False},
#    {'commentID': 107566604,
#     'status': 'approved',
#     'commentSequence': 107566604,
#     'userID': 72872895,
#     'userDisplayName': 'John',
#     'userLocation': 'Cactose',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'The funny thing about activism is that it naturally conveys an absolute confidence in its purpose as right and good and true.  But as things change over time and those positions and actions age, they are often seen in an evolving light.  So while the protesters and many here see this type of mob-activism against historical monuments as absolutely necessary and good, the "retroactive justice" door they are opening won\'t easily be closed.  And therein lies the rub.  Public opinion changes, future generations don\'t relate to prior ones, and the revolving door of purging "offensive" history will continue in perpetuity.',
#     'createDate': '1591964567',
#     'updateDate': '1592150437',
#     'approveDate': '1591964567',
#     'recommendations': 23,
#     'replyCount': 6,
#     'replies': [{'commentID': 107566839,
#       'status': 'approved',
#       'commentSequence': 107566839,
#       'userID': 60787329,
#       'userDisplayName': 'LFK',
#       'userLocation': 'VA',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@John \nTaking down monuments, no matter who does it, does not purge history. History is not a piece of metal, or a name on a sign. History is what we have lived, and we are making history right now.',
#       'createDate': '1591965097',
#       'updateDate': '1591991665',
#       'approveDate': '1591965098',
#       'recommendations': 9,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107566604,
#       'parentUserDisplayName': 'John',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107566839',
#       'isAnonymous': False},
#      {'commentID': 107567246,
#       'status': 'approved',
#       'commentSequence': 107567246,
#       'userID': 72872895,
#       'userDisplayName': 'John',
#       'userLocation': 'Cactose',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@LFK \n\nThat very well may be your truth, but it is important to acknowledge that others, in fact many others, may feel quite differently.  Columbus, through the eyes of Italians and perhaps many other groups, was many good things, not just the cold-hearted killer that Mr. Bouie describes him to be.  In Columbus\'s time, his actions were likely not perceived to be wrong, quite the opposite in fact.  \n\nHistory books acknowledge the monumental achievement of "discovering" the new world, while paying heed to the calamity and destruction it triggered for indigenous peoples.  Purging a statue of Columbus achieves nothing but cowing to the demands of a small minority of people.',
#       'createDate': '1591965989',
#       'updateDate': '1592179360',
#       'approveDate': '1591965990',
#       'recommendations': 10,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107566839,
#       'parentUserDisplayName': 'John',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107567246',
#       'isAnonymous': False},
#      {'commentID': 107567354,
#       'status': 'approved',
#       'commentSequence': 107567354,
#       'userID': 60787329,
#       'userDisplayName': 'LFK',
#       'userLocation': 'VA',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': '@John \nBut you miss my point. A statue is "monument to". It itself is not the history. Removing it does not erase history. The removal and why becomes history.',
#       'createDate': '1591966260',
#       'updateDate': '1591975925',
#       'approveDate': '1591966261',
#       'recommendations': 4,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107567246,
#       'parentUserDisplayName': 'John',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107567354',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107566604',
#     'isAnonymous': False},
#    {'commentID': 107572284,
#     'status': 'approved',
#     'commentSequence': 107572284,
#     'userID': 68809614,
#     'userDisplayName': 'Brewster',
#     'userLocation': 'NJ',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'White supremacy was around long before Trump....\nHypocrisy has been around a long time also...\nWhy George Floyd news coverage and not David Dorn...\nEasy to figure out...David Dorn was not murdered by police ...\nAnd that doesn’t fit the narrative of the current times...\nBut David Dorn was murdered and the source of that murder is treated like it’s caused by white supremacy....',
#     'createDate': '1591976240',
#     'updateDate': '1593014000',
#     'approveDate': '1592018855',
#     'recommendations': 23,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107572284',
#     'isAnonymous': False},
#    {'commentID': 107576150,
#     'status': 'approved',
#     'commentSequence': 107576150,
#     'userID': 86909165,
#     'userDisplayName': 'Mystery Lits',
#     'userLocation': 'somewhere',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'Im waiting for the tolerant Left to start burning books.....  at this rate it is just a matter of time.',
#     'createDate': '1591985467',
#     'updateDate': '1592179706',
#     'approveDate': '1592018287',
#     'recommendations': 23,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107576150',
#     'isAnonymous': False},
#    {'commentID': 107568046,
#     'status': 'approved',
#     'commentSequence': 107568046,
#     'userID': 60857476,
#     'userDisplayName': 'Stephen',
#     'userLocation': 'Jacksonville',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'How many of these people that are so adamant about tearing down Columbus status are doing anything to actually help current Natives? Wanting to take down statues is fine, but there are so many other better things to do to help the underprivileged groups in this country. \n\nDonate to the Native Indian College Fund, or other nonprofits.',
#     'createDate': '1591967842',
#     'updateDate': '1592087917',
#     'approveDate': '1591967843',
#     'recommendations': 22,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107568046',
#     'isAnonymous': False},
#    {'commentID': 107576590,
#     'status': 'approved',
#     'commentSequence': 107576590,
#     'userID': 86909165,
#     'userDisplayName': 'Mystery Lits',
#     'userLocation': 'somewhere',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': None,
#     'commentTitle': '<br\\//>',
#     'commentBody': 'At this rate Leftists will be burning books by the end of the year.',
#     'createDate': '1591986766',
#     'updateDate': '1592172892',
#     'approveDate': '1591995334',
#     'recommendations': 22,
#     'replyCount': 1,
#     'replies': [{'commentID': 107579633,
#       'status': 'approved',
#       'commentSequence': 107579633,
#       'userID': 85290800,
#       'userDisplayName': 'Longtime Japan',
#       'userLocation': 'Japan',
#       'userTitle': 'NULL',
#       'userURL': 'NULL',
#       'picURL': None,
#       'commentTitle': '<br\\//>',
#       'commentBody': 'And then they’ll turn to burning the “witches” that hold views different from their own.',
#       'createDate': '1591999893',
#       'updateDate': '1592148016',
#       'approveDate': '1592016356',
#       'recommendations': 2,
#       'replyCount': 0,
#       'replies': [],
#       'editorsSelection': False,
#       'parentID': 107576590,
#       'parentUserDisplayName': 'Mystery Lits',
#       'depth': 2,
#       'commentType': 'userReply',
#       'trusted': 0,
#       'recommendedFlag': 0,
#       'permID': '107579633',
#       'isAnonymous': False}],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107576590',
#     'isAnonymous': False},
#    {'commentID': 107565651,
#     'status': 'approved',
#     'commentSequence': 107565651,
#     'userID': 67105521,
#     'userDisplayName': 'Peter',
#     'userLocation': 'CT',
#     'userTitle': 'NULL',
#     'userURL': 'NULL',
#     'picURL': 'https://s3.amazonaws.com/pimage.timespeople.nytimes.com/avatars/uncropped-7b66789a57cbfca044a502915590e240a0e2d38926ec2c9389ebb970aef7e089.jpg',
#     'commentTitle': '<br\\//>',
#     'commentBody': 'We need a park dedicated to morally questionable people of consequence from the past (it will have to be a large park...) We don’t want to forget them, but they should be remembered in proper context - alongside memorials and statues honoring the victims of their misadventures. In Moscow there is such a park filled with statues from the soviet era. Surely we can convince Trump to copy the Russians.',
#     'createDate': '1591962058',
#     'updateDate': '1592157415',
#     'approveDate': '1591969764',
#     'recommendations': 21,
#     'replyCount': 0,
#     'replies': [],
#     'editorsSelection': False,
#     'parentID': None,
#     'parentUserDisplayName': None,
#     'depth': 1,
#     'commentType': 'comment',
#     'trusted': 0,
#     'recommendedFlag': 0,
#     'permID': '107565651',
#     'isAnonymous': False}],
#   'depthLimit': 2,
#   'filter': '',
#   'page': 43,
#   'replyLimit': 3,
#   'sort': '',
#   'totalCommentsFound': 1563,
#   'totalCommentsReturned': 43,
#   'totalEditorsSelectionFound': 16,
#   'totalEditorsSelectionReturned': 0,
#   'totalParentCommentsFound': 842,
#   'totalParentCommentsReturned': 25,
#   'totalRecommendationsFound': 1044,
#   'totalRecommendationsReturned': 40,
#   'totalReplyCommentsFound': 721,
#   'totalReplyCommentsReturned': 18,
#   'totalReporterReplyCommentsFound': 0,
#   'totalReporterReplyCommentsReturned': 0,
#   'userData': {'userID': 0,
#    'login': None,
#    'email': '',
#    'displayName': '',
#    'url': '',
#    'title': '',
#    'location': '',
#    'times_people': 0,
#    'sharing': 0,
#    'labels': []}},
#  'errorDetails': ''}

# %%
# isolate just the comments dictionary
comments = (data['results']['comments'])
print(comments)
# Out:
# [{'commentID': 107567029, 'status': 'approved', 'commentSequence': 107567029, 'userID': 57148903, 'userDisplayName': 'Formerly In The Trenches', 'userLocation': 'Atlanta', 'userTitle': 'NULL', 'userURL': 'NULL', 'picURL': None, 'commentTitle': '<br\\//>', 'commentBody': 'I’ve lived in Atlanta for 40 years. On a daily basis I hear people defend the monuments celebrating Confederate “war heroes.” I understand that for some, they can tie one or more family members to what is still referred to as “the war of Northern aggression.” The mindset of the Confederacy is still alive and thriving in the South. There is still anger that is carried from one generation to the next and it boils down to white supremacy. This is still a very strong and powerful ideal within a certain segment of the Southern population. Family historical memory is a powerful, albeit often flawed, determinant.', 'createDate': '1591965553', 'updateDate': '1592155134', 'approveDate': '1591965554', 'recommendations': 38, 'replyCount': 0, 'replies': [], 'editorsSelection': False, 'parentID': None, 'parentUserDisplayName': None, 'depth': 1, 'commentType': 'comment', 'trusted': 0, 'recommendedFlag': 0, 'permID': '107567029', 'isAnonymous': False}, {'commentID': 107566618, 'status': 'approved', 'commentSequence': 107566618, 'userID': 33118370, 'userDisplayName': 'Frank', 'userLocation': 'Boston', 'userTitle': 'NULL', 'userURL': 'NULL', 'picURL': None, 'commentTitle': '<br\\//>', 'commentBody': "While we are at it, let's re-name Columbia University.\n\nAnd re-name the District of Columbia.\n\nBecause sales of naming rights are so lucrative, I think we should hold auctions, just like the Harvard School of Public Health was purchased by Gerald Chan, and the Mt. Sinai School of Medicine was purchased by Carl Icahn.\n\nThat, at least, would have the ring of honesty about who really runs the USA:  The District of Zuckerberg and Buffet University.", 'createDate': '1591964603', 'updateDate': '1592179391', 'approveDate': '1591964604', 'recommendations': 37, 'replyCount': 2, 'replies': [{'commentID': 107569296, 'status': 'approved', 'commentSequence': 107569296, 'userID': 52465399, 'userDisplayName': 'Paul', 'userLocation': 'Philadelphia, PA', 'userTitle': 'NULL', 'userURL': 'NULL', 'picURL': None, 'commentTitle': '<br\\//>', 'commentBody': '@Frank \n"While we are at it, let\'s re-name Columbia University.\nAnd re-name the District of Columbia."\n\nIt\'s long overdue, in fact.', 'createDate': '1591970397', 'updateDate': '1591986933', 'approveDate': '1591984588', 'recommendations': 2, 'replyCount': 0, 'replies': [], 'editorsSelection': False, 'parentID': 107566618, 'parentUserDisplayName': 'Frank', 'depth': 2, 'commentType': 'userReply', 'trusted': 0, 'recommendedFlag': 0, 'permID': '107569296', 'isAnonymous': False}, {'commentID': 107569171, 'status': 'approved', 'commentSequence': 107569171, 'userID': 25676827, 'userDisplayName': 'MDCOOKS8', 'userLocation': 'West Of The Hudson', 'userTitle': 'NULL', 'userURL': 'NULL', 'picURL': 'https://s3.amazonaws.com/pimage.timespeople.nytimes.com/avatars/cropped-7bb04d57fae25e942edf724a48a24f9d8184c9800ff8fe031e4c0b2a6caab0a7.jpg', 'commentTitle': '<br\\//>', 'commentBody': 'Then the name “Amazon” or “Bezos” might become as common as the word “Peach” on street names in Georgia...', 'createDate': '1591970155', 'updateDate': '1592007796', 'approveDate': '1592007796', 'recommendations': 0, 'replyCount': 0, 'replies': [], 'editorsSelection': False, 'parentID': 107566618, 'parentUserDisplayName': 'Frank', 'depth': 2, 'commentType': 'userReply', 'trusted': 0, 'recommendedFlag': 0, 'permID': '107569171', 'isAnonymous': False}], 'editorsSelection': False, 'parentID': None, 'parentUserDisplayName': None, 'depth': 1, 'commentType': 'comment', 'trusted': 0, 'recommendedFlag': 0, 'permID': '107566618', 'isAnonymous': False}, {'commentID': 107567855, 'status': 'approved', 'commentSequence': 107567855, 'userID': 69555093, 'userDisplayName': 'kim', 'userLoc ...

# %%
# look at just one of the comments
one_comment = comments[22]
print(one_comment)
# Out:
# {'commentID': 107568046, 'status': 'approved', 'commentSequence': 107568046, 'userID': 60857476, 'userDisplayName': 'Stephen', 'userLocation': 'Jacksonville', 'userTitle': 'NULL', 'userURL': 'NULL', 'picURL': None, 'commentTitle': '<br\\//>', 'commentBody': 'How many of these people that are so adamant about tearing down Columbus status are doing anything to actually help current Natives? Wanting to take down statues is fine, but there are so many other better things to do to help the underprivileged groups in this country. \n\nDonate to the Native Indian College Fund, or other nonprofits.', 'createDate': '1591967842', 'updateDate': '1592087917', 'approveDate': '1591967843', 'recommendations': 22, 'replyCount': 0, 'replies': [], 'editorsSelection': False, 'parentID': None, 'parentUserDisplayName': None, 'depth': 1, 'commentType': 'comment', 'trusted': 0, 'recommendedFlag': 0, 'permID': '107568046', 'isAnonymous': False}

# %%
# lowercase the comment and remove punctuation
# you can use the code we wrote for the lexical richness exercise to do this
comment_txt = one_comment["commentBody"]
comment_low = comment_txt.lower()
print(comment_low)
# Out:
# how many of these people that are so adamant about tearing down columbus status are doing anything to actually help current natives? wanting to take down statues is fine, but there are so many other better things to do to help the underprivileged groups in this country.
#
# donate to the native indian college fund, or other nonprofits.

# %%
# split text into list

comment2list = comment_low.split(' ') # split the string with a 'space' operator
#print(comment2list)

# create a dictionary of word frequencies!

dict = {}

for word in comment2list:
    if word in dict.keys():
        dict[word] += 1
    else:
        dict[word] = 1
        
print(dict)


# go through each word in text_data
    # if the word isn't in the dictionary, add it as a key AND give it a value of 1
    # if the word IS in the dictionary, add 1 to the value
# Out:
# {'how': 1, 'many': 2, 'of': 1, 'these': 1, 'people': 1, 'that': 1, 'are': 3, 'so': 2, 'adamant': 1, 'about': 1, 'tearing': 1, 'down': 2, 'columbus': 1, 'status': 1, 'doing': 1, 'anything': 1, 'to': 5, 'actually': 1, 'help': 2, 'current': 1, 'natives?': 1, 'wanting': 1, 'take': 1, 'statues': 1, 'is': 1, 'fine,': 1, 'but': 1, 'there': 1, 'other': 2, 'better': 1, 'things': 1, 'do': 1, 'the': 2, 'underprivileged': 1, 'groups': 1, 'in': 1, 'this': 1, 'country.': 1, '\n\ndonate': 1, 'native': 1, 'indian': 1, 'college': 1, 'fund,': 1, 'or': 1, 'nonprofits.': 1}

# %%
# try and plot out a chart of the dictionary we just created!
